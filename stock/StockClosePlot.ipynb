# %%
import tushare as ts
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import time

# %%
ts.set_token('f1e99e550b4835593615bc080fcd1fe08ed3019e51b613ce7aceabae')
pro = ts.pro_api()
pro = ts.pro_api('f1e99e550b4835593615bc080fcd1fe08ed3019e51b613ce7aceabae')

# %%
df = pro.daily(ts_code='600919.SH', start_date='20190518', end_date='20190618')
plt.figure()
df['close'].plot(kind='line')
plt.show()

# %%
df = pro.daily(ts_code='600519.SH', start_date='20160518', end_date='20190618')
sorted_df=df.sort_index(axis=0, ascending=False)
plt.figure()
sorted_df['close'].plot(kind='line')
plt.show()

# %%
df = pro.daily(ts_code='600028.SH', start_date='20160518', end_date='20190618')
sorted_df=df.sort_index(axis=0, ascending=False)
plt.figure()
sorted_df['close'].plot(kind='line')
plt.show()

# %%
df = pro.daily(ts_code='600036.SH', start_date='20160518', end_date='20190618')
sorted_df=df.sort_index(axis=0, ascending=False)
plt.figure()
sorted_df['close'].plot(kind='line')
plt.show()
